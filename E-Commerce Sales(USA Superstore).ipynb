# %% [markdown]
# # Importing dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading the data

# %%
df=pd.read_excel('Superstore_USA.xlsx')

# %%
df.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %% [markdown]
# ## Checking Shape,Columns,Description

# %%
df.shape
# Out:
# (9426, 24)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'order year'],
#       dtype='object')

# %%
df.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   9426.000000  9426.000000  9426.000000    9426.000000  9426.000000
# mean   20241.015277     0.049628    88.303686      12.795142  1738.422236
# min        2.000000     0.000000     0.990000       0.490000     2.000000
# 25%    19330.250000     0.020000     6.480000       3.192500   898.000000
# 50%    21686.500000     0.050000    20.990000       6.050000  1750.000000
# 75%    24042.750000     0.080000    85.990000      13.990000  2578.750000
# max    26399.000000     0.250000  6783.020000     164.730000  3403.000000
# std     6101.890965     0.031798   281.540982      17.181203   979.167197
#
#        Product Base Margin   Postal Code                     Order Date  \
# count          9426.000000   9426.000000                           9426
# mean              0.512189  52446.327286  2012-03-05 18:33:59.465308672
# min               0.350000   1001.000000            2010-01-01 00:00:00
# ...

# %% [markdown]
# # Checking null values

# %%
df.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     72
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %% [markdown]
# # Dealing with null values

# %%
# filling out mean values in the place of null values
df['Product Base Margin'].fillna(df['Product Base Margin'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %% [markdown]
# # Sales and Profit Analysis

# %%
# Distribution of Sales
plt.figure(figsize=(10, 6))
sns.histplot(df['Sales'], bins=50, kde=True)
plt.title('Distribution of Sales')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# Distribution of Profit
plt.figure(figsize=(10, 6))
sns.histplot(df['Profit'], bins=70, kde=True)
plt.title('Distribution of Profit')
plt.xlabel('Profit')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Order Priority

# %%
df['Order Priority'].value_counts()
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1804
# Critical            1
# Name: count, dtype: int64

# %%
df['Order Priority'].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical', 'Critical '],
#       dtype=object)

# %%
df['Order Priority']=df['Order Priority'].replace('Critical ','Critical')

# %%
df['Order Priority'].value_counts()
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1805
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,3))
sns.countplot(x='Order Priority',data=df)
plt.title('Count of Order Priority')
plt.show()

# %% [markdown]
# # Ship Mode

# %%
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: count, dtype: int64

# %%
x=df['Ship Mode'].value_counts().index
y=df['Ship Mode'].value_counts().values

# %%
plt.figure(figsize=(5,4))
plt.pie(y,labels=x,startangle=60,autopct='%0.2f%%')
plt.legend(loc='best')
plt.show()

# %%
plt.figure(figsize=(4,4))
ax=sns.countplot(x='Ship Mode',data=df,palette='magma',hue='Product Category')
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %% [markdown]
# ## Customer Segment

# %%
# plt.figure(figsize=(4,5))
ax=sns.countplot(x='Customer Segment',data=df,palette='coolwarm',)
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# ## Product Category

# %%
plt.figure(figsize=(4,3))
sns.countplot(x='Product Category',data=df,palette='viridis')
plt.show()

# %%
ax=sns.barplot(x='Product Category',y='Profit',data=df,estimator='sum',palette='hsv')
ax.bar_label(ax.containers[0])
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='Product Sub-Category',data=df[df['Product Category']=='Office Supplies'],palette='viridis',
             hue='Product Sub-Category')
plt.xticks(rotation=60)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='Product Sub-Category',data=df[df['Product Category']=='Technology'],palette='plasma',
             hue='Product Sub-Category')
plt.tight_layout()
plt.xticks(rotation=60)
plt.show()

# %%
plt.figure(figsize=(6,5))
ax=sns.countplot(x='Product Sub-Category',data=df[df['Product Category']=='Furniture'],palette='viridis',
             hue='Product Sub-Category')
#plt.xticks(rotation=60)
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
ax=sns.barplot(x='Product Category',y='Product Base Margin',data=df,estimator='sum',palette='coolwarm')
ax.bar_label(ax.containers[0])
plt.show()

# %%
#plt.figure(figsize=(14, 8))
ax=sns.barplot(x='Product Category', y='Sales', data=df, estimator='sum',palette='viridis')
plt.title('Total Sales by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Total Sales')
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# # Dataset information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9426 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %% [markdown]
# ## Order Date

# %%
df['order year']=df['Order Date'].dt.year

# %%
df.shape
# Out:
# (9426, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9426 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %%
df['order year'].value_counts()
# Out:
# order year
# 2013    3054
# 2012    2241
# 2011    2179
# 2010    1952
# Name: count, dtype: int64

# %%
ax=sns.countplot(x='order year',data=df,palette='Spectral')
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# ## State and Province

# %%
df['State or Province'].value_counts().head()
# Out:
# State or Province
# California    1021
# Texas          646
# Illinois       584
# New York       574
# Florida        522
# Name: count, dtype: int64

# %%
sales_by_state = df.groupby('State or Province')['Sales'].sum().reset_index()

# Sort the aggregated sales in descending order
sales_by_state = sales_by_state.sort_values(by='Sales', ascending=False)

#Select the top 10 states with the highest sales
top_states = sales_by_state.head(10)

#Plot the data
plt.figure(figsize=(12, 6))
sns.barplot(x='State or Province', y='Sales', data=top_states, estimator=sum)
plt.title('Top 10 States by Total Sales')
plt.xlabel('State or Province')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Region', y='Profit', data=df, estimator='sum',palette='plasma')
plt.title('Total Profit by Region')
plt.xlabel('Region')
plt.ylabel('Total Profit')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Region', y='Sales', data=df, estimator='sum',palette='Spectral')
plt.title('Total Sales by Region')
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# High-Value Orders:
#             Orders with high and critical priorities should be given special attention as they contribute significantly to sales             profit.

# %% [markdown]
# Corporate Segment:
#             Focus on the Corporate customer segment for marketing and sales strategies, as they are the highest contributors to             sales and profit.

# %% [markdown]
# Product Focus:
#             Invest in promoting Office Supplies and Technology categories, as they have the highest sales and profit margins.

# %% [markdown]
# Regional Strategy:
#             Develop targeted strategies for the Central and West region to maintain and grow its leading position in sales and profit.
